# %%
import os
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, make_scorer, f1_score
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor, XGBClassifier

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical

# import kagglehub

# path = kagglehub.dataset_download("miadul/brain-tumor-dataset")
# os.rename(path, './datasets')

# %% [markdown]
# # make data

# %%
df = pd.read_csv('./datasets/brain_tumor_dataset.csv')
df.columns = [c.lower() for c in df.columns]

stage_to_num = {'I': 1, 'II': 2, 'III': 3, 'IV': 4}
df['stage'] = df['stage'].apply(lambda x: stage_to_num.get(x))
df['all_symptoms'] = df[['symptom_1', 'symptom_2', 'symptom_3']].apply(list, axis=1)
df.drop(['symptom_1', 'symptom_2', 'symptom_3'], axis=1, inplace=True)
df.drop('patient_id', axis=1, inplace=True)

all_symptoms = set().union(*df['all_symptoms'])

for s in all_symptoms:
    df[s.lower().replace(' ', '_')] = df['all_symptoms'].apply(lambda x: 1 if s in x else 0)

for binary_feature in ['radiation_treatment', 'surgery_performed', 'chemotherapy', 'family_history', 'follow_up_required']:
    df[binary_feature] = df[binary_feature].apply(lambda x: 1 if x == 'Yes' else 0)
    
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'Male' else 0)
df['mri_result'] = df['mri_result'].apply(lambda x: 1 if x == 'Positive' else 0)
    
df.drop('all_symptoms', axis=1, inplace=True)

df.head()
# Out:
#    age  gender tumor_type  tumor_size  location        histology  stage  \
# 0   73       1  Malignant    5.375612  Temporal      Astrocytoma      3
# 1   26       1     Benign    4.847098  Parietal     Glioblastoma      2
# 2   31       1     Benign    5.588391  Parietal       Meningioma      1
# 3   29       1  Malignant    1.436600  Temporal  Medulloblastoma      4
# 4   54       0     Benign    2.417506  Parietal     Glioblastoma      1
#
#    radiation_treatment  surgery_performed  chemotherapy  survival_rate  \
# 0                    0                  0             0      51.312579
# 1                    1                  1             1      46.373273
# 2                    0                  0             0      47.072221
# 3                    1                  0             1      51.853634
# 4                    0                  0             1      54.708987
#
#    tumor_growth_rate  family_history  mri_result  follow_up_required  \
# 0           0.111876               0           1                   1
# 1           2.165736               1           1                   1
# 2           1.884228               0           0                   0
# 3           1.283342               1           0                   0
# 4           2.069477               0           1                   1
#
#    vision_issues  seizures  headache  nausea
# 0              1         1         0       0
# 1              0         0         1       1
# 2              1         1         1       0
# 3              1         1         1       0
# 4              0         1         1       0

# %%
df['tumor_type'].unique()
# Out:
# array(['Malignant', 'Benign'], dtype=object)

# %%
df['tumor_type'] = df['tumor_type'].apply(lambda x: 1 if x == 'Malignant' else 0)

# %%
dummies = pd.get_dummies(df[['location', 'histology']], drop_first=True)
dummies.columns = [c.lower() for c in dummies.columns]

# %%
df.drop(['location', 'histology'], axis=1, inplace=True)
df = df.join(dummies)

df.head()
# Out:
#    age  gender  tumor_type  tumor_size  stage  radiation_treatment  \
# 0   73       1           1    5.375612      3                    0
# 1   26       1           0    4.847098      2                    1
# 2   31       1           0    5.588391      1                    0
# 3   29       1           1    1.436600      4                    1
# 4   54       0           0    2.417506      1                    0
#
#    surgery_performed  chemotherapy  survival_rate  tumor_growth_rate  ...  \
# 0                  0             0      51.312579           0.111876  ...
# 1                  1             1      46.373273           2.165736  ...
# 2                  0             0      47.072221           1.884228  ...
# 3                  0             1      51.853634           1.283342  ...
# 4                  0             1      54.708987           2.069477  ...
#
#    vision_issues  seizures  headache  nausea  location_occipital  \
# 0              1         1         0       0                   0
# 1              0         0         1       1                   0
# 2              1         1         1       0                   0
# 3              1         1         1       0                   0
# 4              0         1         1       0                   0
#
#    location_parietal  location_temporal  histology_glioblastoma  \
# 0                  0                  1                       0
# 1                  1                  0                       1
# 2                  1                  0                       0
# 3                  0                  1                       0
# 4                  1                  0                       1
#
#    histology_medulloblastoma  histology_meningioma
# 0                          0                     0
# 1                          0                     0
# 2                          0                     1
# 3                          1                     0
# 4                          0                     0
#
# [5 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# age                          0
# gender                       0
# tumor_type                   0
# tumor_size                   0
# stage                        0
# radiation_treatment          0
# surgery_performed            0
# chemotherapy                 0
# survival_rate                0
# tumor_growth_rate            0
# family_history               0
# mri_result                   0
# follow_up_required           0
# vision_issues                0
# seizures                     0
# headache                     0
# nausea                       0
# location_occipital           0
# location_parietal            0
# location_temporal            0
# histology_glioblastoma       0
# histology_medulloblastoma    0
# histology_meningioma         0
# dtype: int64

# %%
X = df.drop(columns='survival_rate')

# %%
y_num = df['survival_rate']

# %%
def bucket_survival_rate(x):
    if x <= .5:
        return 0
    if .5 < x <= .75:
        return 1
    if .75 < x <= 1:
        return 2

y_cat = df['survival_rate'].apply(lambda x: bucket_survival_rate(x/100))

# %%
y_cat.value_counts()
# Out:
# 1    8386
# 2    8343
# 0    3271
# Name: survival_rate, dtype: int64

# %%
df.describe()
# Out:
#                 age        gender   tumor_type    tumor_size         stage  \
# count  20000.000000  20000.000000  20000.00000  20000.000000  20000.000000
# mean      49.433700      0.499200      0.50150      5.236552      2.495150
# std       17.389296      0.500012      0.50001      2.754359      1.115992
# min       20.000000      0.000000      0.00000      0.500410      1.000000
# 25%       34.000000      0.000000      0.00000      2.836686      2.000000
# 50%       49.000000      0.000000      1.00000      5.200675      2.000000
# 75%       65.000000      1.000000      1.00000      7.624299      3.000000
# max       79.000000      1.000000      1.00000      9.999420      4.000000
#
#        radiation_treatment  surgery_performed  chemotherapy  survival_rate  \
# count         20000.000000       20000.000000  20000.000000   20000.000000
# mean              0.501050           0.503000      0.504850      70.131699
# std               0.500011           0.500004      0.499989      17.270834
# min               0.000000           0.000000      0.000000      40.002386
# 25%               0.000000           0.000000      0.000000      55.224439
# 50%               1.000000           1.000000      1.000000      70.305066
# 75%               1.000000           1.000000      1.000000      85.043395
# max               1.000000           1.000000      1.000000      99.998125
#
#        tumor_growth_rate  ...  vision_issues      seizures      headache  \
# count       20000.000000  ...   20000.000000  20000.000000  20000.000000
# mean            1.547701  ...       0.577400      0.579300      0.578650
# std             0.835995  ...       0.493985      0.493684      0.493788
# min             0.100017  ...       0.000000      0.000000      0.000000
# 25%             0.830433  ...       0.000000      0.000000      0.000000
# 50%             1.541821  ...       1.000000      1.000000      1.000000
# 75%             2.262484  ...       1.000000      1.000000      1.000000
# max             2.999835  ...       1.000000      1.000000      1.000000
#
#              nausea  location_occipital  location_parietal  location_temporal  \
# count  20000.000000        20000.000000       20000.000000       20000.000000
# mean       0.573850            0.248350           0.249500           0.255900
# std        0.494528            0.432067           0.432734           0.436377
# min        0.000000            0.000000           0.000000           0.000000
# 25%        0.000000            0.000000           0.000000           0.000000
# 50%        1.000000            0.000000           0.000000           0.000000
# 75%        1.000000            0.000000           0.000000           1.000000
# max        1.000000            1.000000           1.000000           1.000000
#
#        histology_glioblastoma  histology_medulloblastoma  histology_meningioma
# count            20000.000000               20000.000000          20000.000000
# mean                 0.253400                   0.248950              0.250800
# std                  0.434969                   0.432416              0.433484
# min                  0.000000                   0.000000              0.000000
# 25%                  0.000000                   0.000000              0.000000
# 50%                  0.000000                   0.000000              0.000000
# 75%                  1.000000                   0.000000              1.000000
# max                  1.000000                   1.000000              1.000000
#
# [8 rows x 23 columns]

# %%
corr_matrix = X.corr().abs()
corr_matrix
# Out:
#                                 age    gender  tumor_type  tumor_size  \
# age                        1.000000  0.004163    0.005734    0.014385
# gender                     0.004163  1.000000    0.003795    0.008140
# tumor_type                 0.005734  0.003795    1.000000    0.014354
# tumor_size                 0.014385  0.008140    0.014354    1.000000
# stage                      0.001871  0.000844    0.009620    0.009682
# radiation_treatment        0.002548  0.002303    0.009494    0.015159
# surgery_performed          0.007850  0.002210    0.003818    0.005077
# chemotherapy               0.005843  0.006516    0.004671    0.010469
# tumor_growth_rate          0.009853  0.002592    0.000502    0.004347
# family_history             0.005474  0.001000    0.000201    0.007195
# mri_result                 0.001631  0.001095    0.000891    0.014411
# follow_up_required         0.008890  0.000084    0.013870    0.009102
# vision_issues              0.010567  0.007336    0.014511    0.008058
# seizures                   0.004251  0.009264    0.001292    0.006064
# headache                   0.005764  0.004609    0.005237    0.008125
# nausea                     0.002347  0.001075    0.006413    0.001625
# location_occipital         0.005496  0.000353    0.009710    0.018037
# location_parietal          0.001926  0.007628    0.000812    0.001249
# location_temporal          0.006772  0.006667    0.014053    0.000282
# histology_glioblastoma     0.005090  0.004151    0.000598    0.008104
# histology_medulloblastoma  0.001839  0.009594    0.003924    0.014157
# histology_meningioma       0.002690  0.010148    0.004724    0.005459
#
#                               stage  radiation_treatment  surgery_performed  \
# age                        0.001871             0.002548           0.007850
# gender                     0.000844             0.002303           0.002210
# tumor_type                 0.009620             0.009494           0.003818
# tumor_size                 0.009682             0.015159           0.005077
# stage                      1.000000             0.008880           0.005216
# radiation_treatment        0.008880             1.000000           0.003913
# surgery_performed          0.005216             0.003913           1.000000
# chemotherapy               0.004881             0.010380           0.002842
# tumor_growth_rate          0.001872             0.009088           0.001890
# family_history             0.004256             0.006300           0.002799
# mri_result                 0.008948             0.002194           0.002283
# follow_up_required         0.004435             0.010622           0.003761
# vision_issues              0.004082             0.002050           0.005596
# seizures                   0.016682             0.000439           0.001572
# headache                   0.000329             0.001691           0.000158
# nausea                     0.000558             0.004965           0.007092
# location_occipital         0.002117             0.002149           0.001990
# location_parietal          0.012135             0.008606           0.007171
# location_temporal          0.007924             0.001461           0.002602
# histology_glioblastoma     0.007476             0.008663           0.002806
# histology_medulloblastoma  0.003663             0.002018           0.000361
# histology_meningioma       0.006685             0.000523           0.003010
#
#                            chemotherapy  tumor_growth_rate  family_history  \
# age                            0.005843           0.009853        0.005474
# gender                         0.006516           0.002592        0.001000
# tumor_type                     0.004671           0.000502        0.000201
# tumor_size                     0.010469           0.004347        0.007195
# stage                          0.004881           0.001872        0.004256
# radiation_treatment            0.010380           0.009088        0.006300
# surgery_performed              0.002842           0.001890        0.002799
# chemotherapy                   1.000000           0.004694        0.016103
# tumor_growth_rate              0.004694           1.000000        0.001102
# family_history                 0.016103           0.001102        1.000000
# mri_result                     0.007772           0.001486        0.000301
# follow_up_required             0.000698           0.011625        0.001302
# vision_issues                  0.016397           0.003400        0.007927
# seizures                       0.004901           0.003128        0.000981
# headache                       0.014507           0.011458        0.000474
# nausea                         0.001180           0.001301        0.004520
# location_occipital             0.005460           0.007351        0.000231
# location_parietal              0.003420           0.005232        0.000115
# location_temporal              0.005770           0.003304        0.003779
# histology_glioblastoma         0.006111           0.000387        0.003102
# histology_medulloblastoma      0.001238           0.001107        0.012489
# histology_meningioma           0.002693           0.002932        0.001961
#
#                            ...  vision_issues  seizures  headache    nausea  \
# age                        ...       0.010567  0.004251  0.005764  0.002347
# gender                     ...       0.007336  0.009264  0.004609  0.001075
# tumor_type                 ...       0.014511  0.001292  0.005237  0.006413
# tumor_size                 ...       0.008058  0.006064  0.008125  0.001625
# stage                      ...       0.004082  0.016682  0.000329  0.000558
# radiation_treatment        ...       0.002050  0.000439  0.001691  0.004965
# surgery_performed          ...       0.005596  0.001572  0.000158  0.007092
# chemotherapy               ...       0.016397  0.004901  0.014507  0.001180
# tumor_growth_rate          ...       0.003400  0.003128  0.011458  0.001301
# family_history             ...       0.007927  0.000981  0.000474  0.004520
# mri_result                 ...       0.000556  0.002269  0.004715  0.005489
# follow_up_required         ...       0.000341  0.012659  0.006695  0.000699
# vision_issues              ...       1.000000  0.215647  0.218778  0.213859
# seizures                   ...       0.215647  1.000000  0.220140  0.225215
# headache                   ...       0.218778  0.220140  1.000000  0.212173
# nausea                     ...       0.213859  0.225215  0.212173  1.000000
# location_occipital         ...       0.003293  0.008584  0.010817  0.002735
# location_parietal          ...       0.004029  0.000771  0.011592  0.007830
# location_temporal          ...       0.005304  0.005769  0.004300  0.019240
# histology_glioblastoma     ...       0.001225  0.009522  0.005215  0.007608
# histology_medulloblastoma  ...       0.005121  0.006948  0.003770  0.001590
# histology_meningioma       ...       0.005082  0.007297  0.006426  0.013396
#
#                            location_occipital  location_parietal  \
# age                                  0.005496           0.001926
# gender                               0.000353           0.007628
# tumor_type                           0.009710           0.000812
# tumor_size                           0.018037           0.001249
# stage                                0.002117           0.012135
# radiation_treatment                  0.002149           0.008606
# surgery_performed                    0.001990           0.007171
# chemotherapy                         0.005460           0.003420
# tumor_growth_rate                    0.007351           0.005232
# family_history                       0.000231           0.000115
# mri_result                           0.012336           0.001332
# follow_up_required                   0.008429           0.006194
# vision_issues                        0.003293           0.004029
# seizures                             0.008584           0.000771
# headache                             0.010817           0.011592
# nausea                               0.002735           0.007830
# location_occipital                   1.000000           0.331424
# location_parietal                    0.331424           1.000000
# location_temporal                    0.337088           0.338127
# histology_glioblastoma               0.004885           0.004640
# histology_medulloblastoma            0.002017           0.008481
# histology_meningioma                 0.006067           0.002534
#
#                            location_temporal  histology_glioblastoma  \
# age                                 0.006772                0.005090
# gender                              0.006667                0.004151
# tumor_type                          0.014053                0.000598
# tumor_size                          0.000282                0.008104
# stage                               0.007924                0.007476
# radiation_treatment                 0.001461                0.008663
# surgery_performed                   0.002602                0.002806
# chemotherapy                        0.005770                0.006111
# tumor_growth_rate                   0.003304                0.000387
# family_history                      0.003779                0.003102
# mri_result                          0.005596                0.008656
# follow_up_required                  0.009819                0.005654
# vision_issues                       0.005304                0.001225
# seizures                            0.005769                0.009522
# headache                            0.004300                0.005215
# nausea                              0.019240                0.007608
# location_occipital                  0.337088                0.004885
# location_parietal                   0.338127                0.004640
# location_temporal                   1.000000                0.003978
# histology_glioblastoma              0.003978                1.000000
# histology_medulloblastoma           0.004273                0.335414
# histology_meningioma                0.000900                0.337073
#
#                            histology_medulloblastoma  histology_meningioma
# age                                         0.001839              0.002690
# gender                                      0.009594              0.010148
# tumor_type                                  0.003924              0.004724
# tumor_size                                  0.014157              0.005459
# stage                                       0.003663              0.006685
# radiation_treatment                         0.002018              0.000523
# surgery_performed                           0.000361              0.003010
# chemotherapy                                0.001238              0.002693
# tumor_growth_rate                           0.001107              0.002932
# family_history                              0.012489              0.001961
# mri_result                                  0.003996              0.004089
# follow_up_required                          0.000843              0.003615
# vision_issues                               0.005121              0.005082
# seizures                                    0.006948              0.007297
# headache                                    0.003770              0.006426
# nausea                                      0.001590              0.013396
# location_occipital                          0.002017              0.006067
# location_parietal                           0.008481              0.002534
# location_temporal                           0.004273              0.000900
# histology_glioblastoma                      0.335414              0.337073
# histology_medulloblastoma                   1.000000              0.333109
# histology_meningioma                        0.333109              1.000000
#
# [22 rows x 22 columns]

# %%
# Keep only the upper triangle (excluding the diagonal)
upper = np.triu(corr_matrix, k=1)

# Get column names
colnames = corr_matrix.columns

# Find columns to drop
to_drop = [colnames[i] for i in range(len(colnames)) if any(upper[:, i] > 0.9)]

# Drop them
X = X.drop(columns=to_drop)

# %%
X.shape
# Out:
# (20000, 22)

# %%
X.head()
# Out:
#    age  gender  tumor_type  tumor_size  stage  radiation_treatment  \
# 0   73       1           1    5.375612      3                    0
# 1   26       1           0    4.847098      2                    1
# 2   31       1           0    5.588391      1                    0
# 3   29       1           1    1.436600      4                    1
# 4   54       0           0    2.417506      1                    0
#
#    surgery_performed  chemotherapy  tumor_growth_rate  family_history  ...  \
# 0                  0             0           0.111876               0  ...
# 1                  1             1           2.165736               1  ...
# 2                  0             0           1.884228               0  ...
# 3                  0             1           1.283342               1  ...
# 4                  0             1           2.069477               0  ...
#
#    vision_issues  seizures  headache  nausea  location_occipital  \
# 0              1         1         0       0                   0
# 1              0         0         1       1                   0
# 2              1         1         1       0                   0
# 3              1         1         1       0                   0
# 4              0         1         1       0                   0
#
#    location_parietal  location_temporal  histology_glioblastoma  \
# 0                  0                  1                       0
# 1                  1                  0                       1
# 2                  1                  0                       0
# 3                  0                  1                       0
# 4                  1                  0                       1
#
#    histology_medulloblastoma  histology_meningioma
# 0                          0                     0
# 1                          0                     0
# 2                          0                     1
# 3                          1                     0
# 4                          0                     0
#
# [5 rows x 22 columns]

# %% [markdown]
# # regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_num)

# %% [markdown]
# ## vanilla

# %%
regression_pipelines = {
    'linreg': make_pipeline(StandardScaler(), LinearRegression()),
    'rf': make_pipeline(RandomForestRegressor()),
    'xgb': make_pipeline(XGBRegressor())
}

# %%
for key, val in regression_pipelines.items():
    val.fit(X_train, y_train)
    y_pred = val.predict(X_test)
    rmse = mean_squared_error(y_test, y_pred)
    print(f'RMSE for {key}: {rmse}')

# %%
rmse_scorer = make_scorer(mean_squared_error, greater_is_better=False)

xgbr_params = {
    'n_estimators': [100, 200],
    'max_depth': [3, 5],
    'learning_rate': [.05, .01]
}

grid_xgbr = GridSearchCV(XGBRegressor(), param_grid = xgbr_params, scoring=rmse_scorer, cv=5)
grid_xgbr.fit(X_train, y_train)

# %%
print(f'best rmse: {-grid_xgbr.best_score_}')
grid_xgbr.best_estimator_

# %% [markdown]
# ## deep learning

# %%
model = Sequential()

model.add(Dense(64, input_dim = X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

model.compile(optimizer=Adam(learning_rate=.001), loss='mse')

early_stopping = EarlyStopping(monitor='val_loss', patience=10)

model.fit(X_train, y_train, epochs=100, batch_size=32, callbacks=[early_stopping], validation_split=.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 1s 2ms/step - loss: 1036.3494 - val_loss: 460.5389
# Epoch 2/100
# 375/375 [==============================] - 1s 2ms/step - loss: 414.3580 - val_loss: 390.3017
# Epoch 3/100
# 375/375 [==============================] - 1s 2ms/step - loss: 384.1790 - val_loss: 374.7924
# Epoch 4/100
# 375/375 [==============================] - 1s 2ms/step - loss: 372.1896 - val_loss: 362.1884
# Epoch 5/100
# 375/375 [==============================] - 1s 2ms/step - loss: 365.4644 - val_loss: 355.4239
# Epoch 6/100
# 375/375 [==============================] - 1s 2ms/step - loss: 359.2219 - val_loss: 348.2837
# Epoch 7/100
# 375/375 [==============================] - 1s 2ms/step - loss: 352.9506 - val_loss: 343.1913
# Epoch 8/100
# 375/375 [==============================] - 1s 2ms/step - loss: 347.2101 - val_loss: 339.5349
# Epoch 9/100
# 375/375 [==============================] - 1s 1ms/step - loss: 342.7285 - val_loss: 336.5046
# Epoch 10/100
# 375/375 [==============================] - 1s 1ms/step - loss: 338.0598 - val_loss: 332.1492
# Epoch 11/100
# 375/375 [==============================] - 0s 1ms/step - loss: 333.7437 - val_loss: 341.3842
# Epoch 12/100
# 375/375 [==============================] - 1s 1ms/step - loss: 327.9530 - val_loss: 335.2838
# Epoch 13/100
# 375/375 [==============================] - 1s 1ms/step - loss: 324.1824 - val_loss: 324.4300
# Epoch 14/100
# 375/375 [==============================] - 0s 1ms/step - loss: 321.2464 - val_loss: 314.5284
# Epoch 15/100
# 375/375 [==============================] - 0s 1ms/step - loss: 316.2800 - val_loss: 310.9969
# Epoch 16/100
# 375/375 [==============================] - 0s 1ms/step - loss: 313.5877 - val_loss: 308.2484
# Epoch 17/100
# 375/375 [==============================] - 1s 1ms/step - loss: 310.6790 - val_loss: 311.4502
# Epoch 18/100
# 375/375 [==============================] - 1s 1ms/step - loss: 306.5351 - val_loss: 304.0793
# Epoch 19/100
# 375/375 [==============================] - 1s 1ms/step - loss: 305.2427 - val_loss: 304.2003
# Epoch 20/100
# 375/375 [==============================] - 1s 1ms/step - loss: 305.1699 - val_loss: 302.3735
# Epoch 21/100
# 375/375 [==============================] - 0s 1ms/step - loss: 302.1496 - val_loss: 301.6218
# Epoch 22/100
# 375/375 [==============================] - 1s 1ms/step - loss: 304.0507 - val_loss: 303.0581
# Epoch 23/100
# 375/375 [==============================] - 0s 1ms/step - loss: 303.1360 - val_loss: 306.5158
# Epoch 24/100
# 375/375 [==============================] - 0s 1ms/step - loss: 301.1965 - val_loss: 299.5865
# Epoch 25/100
# 375/375 [==============================] - 1s 1ms/step - loss: 302.6782 - val_loss: 311.1842
# Epoch 26/100
# 375/375 [==============================] - 1s 1ms/step - loss: 301.1169 - val_loss: 308.7558
# Epoch 27/100
# 375/375 [==============================] - 0s 1ms/step - loss: 301.7180 - val_loss: 300.3311
# Epoch 28/100
# 375/375 [==============================] - 1s 1ms/step - loss: 300.9882 - val_loss: 307.1521
# Epoch 29/100
# 375/375 [==============================] - 0s 1ms/step - loss: 302.8169 - val_loss: 299.4757
# Epoch 30/100
# 375/375 [==============================] - 1s 1ms/step - loss: 300.6414 - val_loss: 307.5005
# Epoch 31/100
# 375/375 [==============================] - 1s 1ms/step - loss: 301.6771 - val_loss: 299.7886
# Epoch 32/100
# 375/375 [==============================] - 1s 1ms/step - loss: 300.7997 - val_loss: 300.0456
# Epoch 33/100
# 375/375 [==============================] - 1s 1ms/step - loss: 300.8505 - val_loss: 300.3956
# Epoch 34/100
# 375/375 [==============================] - 0s 1ms/step - loss: 300.9459 - val_loss: 301.4122
# Epoch 35/100
# 375/375 [==============================] - 1s 1ms/step - loss: 300.3350 - val_loss: 299.7763
# Epoch 36/100
# 375/375 [==============================] - 0s 1ms/step - loss: 301.8367 - val_loss: 301.5180
# Epoch 37/100
# 375/375 [==============================] - 0s 1ms/step - loss: 301.0740 - val_loss: 302.6907
# Epoch 38/100
# 375/375 [==============================] - 1s 1ms/step - loss: 301.0097 - val_loss: 300.1724
# Epoch 39/100
# 375/375 [==============================] - 1s 1ms/step - loss: 301.1102 - val_loss: 304.9044

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 157/157 [==============================] - 0s 944us/step
# array([[68.54686 ],
#        [70.48219 ],
#        [68.5229  ],
#        ...,
#        [66.69813 ],
#        [67.130295],
#        [65.90346 ]], dtype=float32)

# %% [markdown]
# # classification

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_cat)

# %% [markdown]
# ## vanilla

# %%
classification_pipelines = {
    'logreg': make_pipeline(StandardScaler(), LogisticRegression(multi_class='multinomial')),
    'xgb': make_pipeline(XGBClassifier(objective='multi:softprob', num_class = 3))
}

# %%
for key, val in classification_pipelines.items():
    val.fit(X_train, y_train)
    y_pred = val.predict(X_test)
    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f'f1_score for {key}: {f1}')

# %%
f1_scorer = make_scorer(f1_score, average='macro')

xgbc_params = {
    'n_estimators': [100, 200],
    'max_depth': [3, 5],
    'learning_rate': [.05, .01]
}

grid_xgbc = GridSearchCV(XGBClassifier(), param_grid = xgbc_params, scoring=f1_scorer, cv=5)
grid_xgbc.fit(X_train, y_train)

# %% [markdown]
# ## deep learning

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()

model.add(Dense(64, input_dim = X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer=Adam(learning_rate=.001), loss='categorical_crossentropy')

early_stopping = EarlyStopping(monitor='val_loss', patience=10)

model.fit(X_train, y_train, epochs=100, batch_size=32, callbacks=[early_stopping], validation_split=.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 1s 2ms/step - loss: 1.0998 - val_loss: 1.0436
# Epoch 2/100
# 375/375 [==============================] - 1s 2ms/step - loss: 1.0446 - val_loss: 1.0733
# Epoch 3/100
# 375/375 [==============================] - 1s 2ms/step - loss: 1.0455 - val_loss: 1.0645
# Epoch 4/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0398 - val_loss: 1.0570
# Epoch 5/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0390 - val_loss: 1.0671
# Epoch 6/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0375 - val_loss: 1.0466
# Epoch 7/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0414 - val_loss: 1.0601
# Epoch 8/100
# 375/375 [==============================] - 1s 2ms/step - loss: 1.0357 - val_loss: 1.0476
# Epoch 9/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0354 - val_loss: 1.0417
# Epoch 10/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0327 - val_loss: 1.0417
# Epoch 11/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0317 - val_loss: 1.0394
# Epoch 12/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0323 - val_loss: 1.0472
# Epoch 13/100
# 375/375 [==============================] - 0s 1ms/step - loss: 1.0328 - val_loss: 1.0429
# Epoch 14/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0286 - val_loss: 1.0557
# Epoch 15/100
# 375/375 [==============================] - 0s 1ms/step - loss: 1.0287 - val_loss: 1.0415
# Epoch 16/100
# 375/375 [==============================] - 0s 1ms/step - loss: 1.0272 - val_loss: 1.0656
# Epoch 17/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0275 - val_loss: 1.0428
# Epoch 18/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0257 - val_loss: 1.0432
# Epoch 19/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0237 - val_loss: 1.0454
# Epoch 20/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0234 - val_loss: 1.0484
# Epoch 21/100
# 375/375 [==============================] - 1s 1ms/step - loss: 1.0223 - val_loss: 1.0404

# %%
model.predict(X_test)
# Out:
# 157/157 [==============================] - 0s 967us/step
# array([[0.18684736, 0.4066395 , 0.40651312],
#        [0.12475654, 0.47998777, 0.39525574],
#        [0.18522699, 0.42426735, 0.39050564],
#        ...,
#        [0.17236233, 0.4216576 , 0.40598008],
#        [0.13770398, 0.428129  , 0.43416697],
#        [0.18208106, 0.44236118, 0.3755578 ]], dtype=float32)
